# %%
import glob
import pandas as pd
import numpy as np
import matplotlib


path =r'Coinmarketcap/new24' # use your path
allFiles = glob.glob(path + "/*.csv")
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap()

cmc.ticker(convert="BTC")
# Out:
# {'active_assets': 702,
#  'active_currencies': 896,
#  'active_markets': 10414,
#  'bitcoin_percentage_of_market_cap': 37.83,
#  'last_updated': 1524791673,
#  'total_24h_volume_usd': 27629562273.0,
#  'total_market_cap_usd': 415537623876.0}

# %%
from datetime import datetime
start, end = (datetime(2017, 9, 30), datetime(2017, 10, 10))
coinmarketcap.historical("BTC", start, end)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6883cf69677c> in <module>()
#       1 from datetime import datetime
#       2 start, end = (datetime(2017, 9, 30), datetime(2017, 10, 10))
# ----> 3 coinmarketcap.historical("BTC", start, end)
#
# NameError: name 'coinmarketcap' is not defined

# %%
cmc.symbols()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-b215fc686de3> in <module>()
# ----> 1 cmc.symbol()
#
# AttributeError: 'pymarketcap.core.Pymarketcap' object has no attribute 'symbol'

# %%
import asyncio
from pymarketcap import AsyncPymarketcap

async def main():
    async with AsyncPymarketcap() as apym:
        async for currency in apym.every_currency():
            print(currency)

if __name__ == '__main__':
    loop = asyncio.get_event_loop()
    loop.run_until_complete(main())
# Out:
# {'market_cap_by_available_supply': [[datetime.datetime(2013, 4, 28, 14, 47, 21),
#    1500517590],
#   [datetime.datetime(2013, 4, 29, 14, 45, 1), 1575032004],
#   [datetime.datetime(2013, 4, 30, 14, 45, 2), 1501657492],
#   [datetime.datetime(2013, 5, 1, 14, 45, 2), 1298951550],
#   [datetime.datetime(2013, 5, 2, 15, 20, 1), 1148667722],
#   [datetime.datetime(2013, 5, 3, 15, 20, 1), 1011066494],
#   [datetime.datetime(2013, 5, 4, 15, 20, 1), 1236351843],
#   [datetime.datetime(2013, 5, 5, 15, 25, 1), 1298377788],
#   [datetime.datetime(2013, 5, 6, 15, 25, 3), 1315992303],
#   [datetime.datetime(2013, 5, 7, 15, 25, 1), 1183766500],
#   [datetime.datetime(2013, 5, 8, 15, 25, 1), 1253655040],
#   [datetime.datetime(2013, 5, 9, 15, 50, 1), 1258130700],
#   [datetime.datetime(2013, 5, 10, 15, 55, 2), 1322989457],
#   [datetime.datetime(2013, 5, 11, 16, 25, 1), 1259239352],
#   [datetime.datetime(2013, 5, 12, 16, 25, 1), 1278708678],
# ...
